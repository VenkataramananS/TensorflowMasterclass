# %% [markdown]
# <a href="https://colab.research.google.com/github/VenkataramananS/TensorflowMasterclass/blob/main/01_neural_network_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create features
X = np.array([-10.0, -7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0, 17.0, 20.0, 23.0])

# Create labels
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0, 27.0, 30.0, 33.0, 36.0])

# Visualizing
plt.scatter(X,y)

# %%
y == X + 13
# logic for neural network to learn
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %% [markdown]
# ## Input and Output shapes

# %%
X.shape,y.shape
# Out:
# ((12,), (12,))

# %%
 # Changing data into tensors
 X = tf.constant(X)
 y = tf.constant(y)
 X,y
# Out:
# (<tf.Tensor: shape=(12,), dtype=float64, numpy=
#  array([-10.,  -7.,  -4.,  -1.,   2.,   5.,   8.,  11.,  14.,  17.,  20.,
#          23.])>,
#  <tf.Tensor: shape=(12,), dtype=float64, numpy=array([ 3.,  6.,  9., 12., 15., 18., 21., 24., 27., 30., 33., 36.])>)

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model using Sequential API
model = tf.keras.Sequential([tf.keras.layers.Dense(1, input_shape=(1,))])

# Compiling the model
model.compile(loss = tf.keras.losses.mae, optimizer = tf.keras.optimizers.SGD(), metrics = ["mae"])

# Fitting the model
model.fit(X,y, epochs = 2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 275ms/step - loss: 15.7946 - mae: 15.7946
# Epoch 2/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 15.3621 - mae: 15.3621
# Epoch 3/2000
# 1/1 [==============================] - 0s 7ms/step - loss: 14.9296 - mae: 14.9296
# Epoch 4/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 14.4971 - mae: 14.4971
# Epoch 5/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 14.0646 - mae: 14.0646
# Epoch 6/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 13.6321 - mae: 13.6321
# Epoch 7/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 13.1996 - mae: 13.1996
# Epoch 8/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 12.7671 - mae: 12.7671
# Epoch 9/2000
# 1/1 [==============================] - 0s 6ms/step - loss: 12.3346 - mae: 12.3346
# Epoch 10/2000
# 1/1 [==============================] - 0s 5ms/step - loss: 11.9021 - mae: 11.9021
# ...

# %%
model.predict([5.0])
# Out:
# 1/1 [==============================] - 0s 32ms/step
# array([[18.103777]], dtype=float32)
